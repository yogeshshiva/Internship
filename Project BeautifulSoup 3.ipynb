# %% [markdown]
# # Project

# %% [raw]
# Question ) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
team = []
for i in soup.find_all('span',class_="u-hide-phablet"):
    team.append(i.text)
team
# Out:
# ['Australia',
#  'England',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Bangladesh',
#  'Thailand',
#  'Pakistan',
#  'Sri Lanka',
#  'Ireland',
#  'Netherlands',
#  'Zimbabwe']

# %%
match = []
for i in soup.find_all('td',class_="rankings-block__banner--matches"):
    match.append(i.text)
match
# Out:
# ['21']

# %%
matches = []
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    matches.append(i.text)
a = matches[::2]
print(a)
# Out:
# ['28', '26', '27', '25', '27', '13', '8', '27', '8', '14', '9', '8']

# %%
point = []
for i in soup.find_all('td',class_="rankings-block__banner--points"):
    point.append(i.text)
point
# Out:
# ['3,603']

# %%
points = []
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    points.append(i.text)
b = points[1::2]
print(b)
# Out:
# ['3,342', '3,098', '2,820', '2,553', '2,535', '983', '572', '1,678', '353', '548', '0', '0']

# %%
rating = []
for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    rating.append(i.text.split('\n                            ')[1])
rating
# Out:
# ['172']

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    ratings.append(i.text)
ratings
# Out:
# ['119', '119', '104', '102', '94', '76', '72', '62', '44', '39', '0', '0']

# %%
c = rating + ratings
c
# Out:
# ['172',
#  '119',
#  '119',
#  '104',
#  '102',
#  '94',
#  '76',
#  '72',
#  '62',
#  '44',
#  '39',
#  '0',
#  '0']

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Team":team[0:10],"Matches":a[0:10],"Points":b[0:10],"Ratings":c[0:10]})
df
# Out:
#            Team Matches Points Ratings
# 0     Australia      28  3,342     172
# 1       England      26  3,098     119
# 2  South Africa      27  2,820     119
# 3         India      25  2,553     104
# 4   New Zealand      27  2,535     102
# 5   West Indies      13    983      94
# 6    Bangladesh       8    572      76
# 7      Thailand      27  1,678      72
# 8      Pakistan       8    353      62
# 9     Sri Lanka      14    548      44

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
Batting = []
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    Batting.append(i.text)
Batting
# Out:
# ['Alyssa Healy']

# %%
Battings = []
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    Battings.append(i.text.split('\n')[1])
Battings
# Out:
# ['Beth Mooney',
#  'Laura Wolvaardt',
#  'Natalie Sciver',
#  'Meg Lanning',
#  'Harmanpreet Kaur',
#  'Smriti Mandhana',
#  'Rachael Haynes',
#  'Chamari Athapaththu',
#  'Amy Satterthwaite',
#  'Ellyse Perry',
#  'Tammy Beaumont',
#  'Deandra Dottin',
#  'Stafanie Taylor',
#  'Suzie Bates',
#  'Amelia Kerr',
#  'Marizanne Kapp',
#  'Hayley Matthews',
#  'Danielle Wyatt',
#  'Chloe-Lesleigh Tryon',
#  'Heather Knight',
#  'Bismah Maroof',
#  'Mignon du Preez',
#  'Sophie Devine',
#  'Deepti Sharma',
#  'Amy Jones',
#  'Sidra Ameen',
#  'Maddie Green',
#  'Ashleigh Gardner',
#  'Sune Luus',
#  'Gaby Lewis',
#  'Nida Dar',
#  'Laura Delany',
#  'Sophia Dunkley',
#  'Fargana Hoque',
#  'Tahlia McGrath',
#  'Aliya Riaz',
#  'Yastika Bhatia',
#  'Shafali Verma',
#  'Nigar Sultana',
#  'Harshitha Madavi',
#  'Rumana Ahmed',
#  'Nahida Khan',
#  'Poonam Raut',
#  'Muneeba Ali',
#  'Umaima Sohail',
#  'Babette de Leede',
#  'Lara Goodall',
#  'Nattakan Chantam',
#  'Amy Hunter',
# ...

# %%
a = Batting + Battings
a
# Out:
# ['Alyssa Healy',
#  'Beth Mooney',
#  'Laura Wolvaardt',
#  'Natalie Sciver',
#  'Meg Lanning',
#  'Harmanpreet Kaur',
#  'Smriti Mandhana',
#  'Rachael Haynes',
#  'Chamari Athapaththu',
#  'Amy Satterthwaite',
#  'Ellyse Perry',
#  'Tammy Beaumont',
#  'Deandra Dottin',
#  'Stafanie Taylor',
#  'Suzie Bates',
#  'Amelia Kerr',
#  'Marizanne Kapp',
#  'Hayley Matthews',
#  'Danielle Wyatt',
#  'Chloe-Lesleigh Tryon',
#  'Heather Knight',
#  'Bismah Maroof',
#  'Mignon du Preez',
#  'Sophie Devine',
#  'Deepti Sharma',
#  'Amy Jones',
#  'Sidra Ameen',
#  'Maddie Green',
#  'Ashleigh Gardner',
#  'Sune Luus',
#  'Gaby Lewis',
#  'Nida Dar',
#  'Laura Delany',
#  'Sophia Dunkley',
#  'Fargana Hoque',
#  'Tahlia McGrath',
#  'Aliya Riaz',
#  'Yastika Bhatia',
#  'Shafali Verma',
#  'Nigar Sultana',
#  'Harshitha Madavi',
#  'Rumana Ahmed',
#  'Nahida Khan',
#  'Poonam Raut',
#  'Muneeba Ali',
#  'Umaima Sohail',
#  'Babette de Leede',
#  'Lara Goodall',
#  'Nattakan Chantam',
# ...

# %%
team = []
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    team.append(i.text.split('\n')[2])
team
# Out:
# ['AUS']

# %%
teams = []
for i in soup.find_all('span',class_="table-body__logo-text"):
    teams.append(i.text)
teams
# Out:
# ['AUS',
#  'SA',
#  'ENG',
#  'AUS',
#  'IND',
#  'IND',
#  'AUS',
#  'SL',
#  'NZ',
#  'AUS',
#  'ENG',
#  'WI',
#  'WI',
#  'NZ',
#  'NZ',
#  'SA',
#  'WI',
#  'ENG',
#  'SA',
#  'ENG',
#  'PAK',
#  'SA',
#  'NZ',
#  'IND',
#  'ENG',
#  'PAK',
#  'NZ',
#  'AUS',
#  'SA',
#  'IRE',
#  'PAK',
#  'IRE',
#  'ENG',
#  'BAN',
#  'AUS',
#  'PAK',
#  'IND',
#  'IND',
#  'BAN',
#  'SL',
#  'BAN',
#  'PAK',
#  'IND',
#  'PAK',
#  'PAK',
#  'NED',
#  'SA',
#  'THA',
#  'IRE',
#  'ENG',
#  'SL',
#  'IND',
#  'IRE',
#  'SA',
#  'PAK',
#  'NZ',
#  'AUS',
#  'ENG',
#  'NZ',
#  'BAN',
#  'WI',
#  'BAN',
#  'SA',
#  'SA',
#  'ENG',
#  'IND',
#  'ENG',
#  'WI',
#  'IND',
#  'IRE',
#  'SL',
#  'BAN',
#  'AUS',
#  'NZ',
#  'ENG',
#  'WI',
#  'SL',
#  'WI',
#  'SL',
#  'BAN',
#  'AUS',
#  'IRE',
#  'THA',
#  'AUS',
#  'IND',
#  'IRE',
#  'ZIM',
#  'BAN',
#  'ENG',
#  'THA',
#  'IRE',
#  'WI',
#  'BAN',
#  'IND',
#  'NZ',
#  'THA',
#  'SA',
#  'ZIM',
#  'NED']

# %%
b = team + teams
print(b)
# Out:
# ['AUS', 'AUS', 'SA', 'ENG', 'AUS', 'IND', 'IND', 'AUS', 'SL', 'NZ', 'AUS', 'ENG', 'WI', 'WI', 'NZ', 'NZ', 'SA', 'WI', 'ENG', 'SA', 'ENG', 'PAK', 'SA', 'NZ', 'IND', 'ENG', 'PAK', 'NZ', 'AUS', 'SA', 'IRE', 'PAK', 'IRE', 'ENG', 'BAN', 'AUS', 'PAK', 'IND', 'IND', 'BAN', 'SL', 'BAN', 'PAK', 'IND', 'PAK', 'PAK', 'NED', 'SA', 'THA', 'IRE', 'ENG', 'SL', 'IND', 'IRE', 'SA', 'PAK', 'NZ', 'AUS', 'ENG', 'NZ', 'BAN', 'WI', 'BAN', 'SA', 'SA', 'ENG', 'IND', 'ENG', 'WI', 'IND', 'IRE', 'SL', 'BAN', 'AUS', 'NZ', 'ENG', 'WI', 'SL', 'WI', 'SL', 'BAN', 'AUS', 'IRE', 'THA', 'AUS', 'IND', 'IRE', 'ZIM', 'BAN', 'ENG', 'THA', 'IRE', 'WI', 'BAN', 'IND', 'NZ', 'THA', 'SA', 'ZIM', 'NED']

# %%
rating = []
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    rating.append(i.text)
rating
# Out:
# ['762']

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell rating"):
    ratings.append(i.text)
ratings
# Out:
# ['754',
#  '732',
#  '731',
#  '717',
#  '716',
#  '714',
#  '680',
#  '655',
#  '641',
#  '626',
#  '595',
#  '589',
#  '588',
#  '588',
#  '587',
#  '585',
#  '566',
#  '566',
#  '557',
#  '555',
#  '551',
#  '548',
#  '548',
#  '547',
#  '535',
#  '522',
#  '509',
#  '507',
#  '496',
#  '485',
#  '476',
#  '475',
#  '465',
#  '462',
#  '448',
#  '432',
#  '426',
#  '405',
#  '403',
#  '402',
#  '399',
#  '398',
#  '397',
#  '395',
#  '395',
#  '394',
#  '394',
#  '386',
#  '385',
#  '384',
#  '384',
#  '380',
#  '372',
#  '363',
#  '360',
#  '346',
#  '346',
#  '345',
#  '337',
#  '333',
#  '323',
#  '320',
#  '314',
#  '311',
#  '310',
#  '307',
#  '305',
#  '304',
#  '302',
#  '298',
#  '298',
#  '296',
#  '285',
#  '276',
#  '273',
#  '272',
#  '267',
#  '266',
#  '266',
#  '266',
#  '265',
#  '263',
#  '257',
#  '253',
#  '253',
#  '247',
#  '244',
#  '241',
#  '239',
#  '235',
#  '232',
#  '231',
#  '228',
#  '228',
#  '226',
#  '225',
#  '224',
#  '222',
#  '222']

# %%
c = rating + ratings
print(c)
# Out:
# ['762', '754', '732', '731', '717', '716', '714', '680', '655', '641', '626', '595', '589', '588', '588', '587', '585', '566', '566', '557', '555', '551', '548', '548', '547', '535', '522', '509', '507', '496', '485', '476', '475', '465', '462', '448', '432', '426', '405', '403', '402', '399', '398', '397', '395', '395', '394', '394', '386', '385', '384', '384', '380', '372', '363', '360', '346', '346', '345', '337', '333', '323', '320', '314', '311', '310', '307', '305', '304', '302', '298', '298', '296', '285', '276', '273', '272', '267', '266', '266', '266', '265', '263', '257', '253', '253', '247', '244', '241', '239', '235', '232', '231', '228', '228', '226', '225', '224', '222', '222']

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Batting_Player":a[0:10],"Team":b[0:10],"Ratings":c[0:10]})
df
# Out:
#         Batting_Player Team Ratings
# 0         Alyssa Healy  AUS     762
# 1          Beth Mooney  AUS     754
# 2      Laura Wolvaardt   SA     732
# 3       Natalie Sciver  ENG     731
# 4          Meg Lanning  AUS     717
# 5     Harmanpreet Kaur  IND     716
# 6      Smriti Mandhana  IND     714
# 7       Rachael Haynes  AUS     680
# 8  Chamari Athapaththu   SL     655
# 9    Amy Satterthwaite   NZ     641

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI All Rounder | Player Rankings | ICC" property="og:title"/>
# ...

# %%
all_rounder = []
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    all_rounder.append(i.text)
all_rounder
# Out:
# ['Hayley Matthews']

# %%
all_rounders = []
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    all_rounders.append(i.text.split('\n')[1])
all_rounders
# Out:
# ['Natalie Sciver',
#  'Ellyse Perry',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Ashleigh Gardner',
#  'Jess Jonassen',
#  'Nida Dar',
#  'Jhulan Goswami',
#  'Sophie Ecclestone',
#  'Sophie Devine',
#  'Chloe-Lesleigh Tryon',
#  'Katherine Brunt',
#  'Rumana Ahmed',
#  'Stafanie Taylor',
#  'Chamari Athapaththu',
#  'Charlotte Dean',
#  'Sune Luus',
#  'Salma Khatun']

# %%
a = all_rounder + all_rounders
a
# Out:
# ['Hayley Matthews',
#  'Natalie Sciver',
#  'Ellyse Perry',
#  'Marizanne Kapp',
#  'Amelia Kerr',
#  'Deepti Sharma',
#  'Ashleigh Gardner',
#  'Jess Jonassen',
#  'Nida Dar',
#  'Jhulan Goswami',
#  'Sophie Ecclestone',
#  'Sophie Devine',
#  'Chloe-Lesleigh Tryon',
#  'Katherine Brunt',
#  'Rumana Ahmed',
#  'Stafanie Taylor',
#  'Chamari Athapaththu',
#  'Charlotte Dean',
#  'Sune Luus',
#  'Salma Khatun']

# %%
team = []
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    team.append(i.text.split('\n')[2])
team
# Out:
# ['WI']

# %%
teams = []
for i in soup.find_all('span',class_="table-body__logo-text"):
    teams.append(i.text)
teams
# Out:
# ['ENG',
#  'AUS',
#  'SA',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'PAK',
#  'IND',
#  'ENG',
#  'NZ',
#  'SA',
#  'ENG',
#  'BAN',
#  'WI',
#  'SL',
#  'ENG',
#  'SA',
#  'BAN']

# %%
b = team + teams
b
# Out:
# ['WI',
#  'ENG',
#  'AUS',
#  'SA',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'PAK',
#  'IND',
#  'ENG',
#  'NZ',
#  'SA',
#  'ENG',
#  'BAN',
#  'WI',
#  'SL',
#  'ENG',
#  'SA',
#  'BAN']

# %%
rating = []
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    rating.append(i.text)
rating
# Out:
# ['373']

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell rating"):
    ratings.append(i.text)
ratings
# Out:
# ['371',
#  '366',
#  '349',
#  '336',
#  '322',
#  '292',
#  '250',
#  '232',
#  '214',
#  '205',
#  '202',
#  '197',
#  '195',
#  '184',
#  '181',
#  '178',
#  '174',
#  '171',
#  '169']

# %%
c = rating + ratings
c
# Out:
# ['373',
#  '371',
#  '366',
#  '349',
#  '336',
#  '322',
#  '292',
#  '250',
#  '232',
#  '214',
#  '205',
#  '202',
#  '197',
#  '195',
#  '184',
#  '181',
#  '178',
#  '174',
#  '171',
#  '169']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'All_Rounder':a[0:10],'Team':b[0:10],'Rating':c[0:10]})
df
# Out:
#         All_Rounder Team Rating
# 0   Hayley Matthews   WI    373
# 1    Natalie Sciver  ENG    371
# 2      Ellyse Perry  AUS    366
# 3    Marizanne Kapp   SA    349
# 4       Amelia Kerr   NZ    336
# 5     Deepti Sharma  IND    322
# 6  Ashleigh Gardner  AUS    292
# 7     Jess Jonassen  AUS    250
# 8          Nida Dar  PAK    232
# 9    Jhulan Goswami  IND    214
