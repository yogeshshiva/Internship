# %% [markdown]
# # Project

# %% [raw]
# Question ) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team andrating.
# c) Top 10 ODI bowlers along with the records of their team andrating.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
team = []
for i in soup.find_all('span',class_="u-hide-phablet"):
    team.append(i.text)
team
# Out:
# ['Australia',
#  'New Zealand',
#  'India',
#  'England',
#  'Pakistan',
#  'South Africa',
#  'Bangladesh',
#  'Sri Lanka',
#  'West Indies',
#  'Afghanistan',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Nepal',
#  'Oman',
#  'Netherlands',
#  'United States',
#  'Namibia',
#  'UAE',
#  'Papua New Guinea']

# %%
match = [] 
for i in soup.find('td',class_="rankings-block__banner--matches"):
    match.append(i.text)
match
# Out:
# ['35']

# %%
matche = []
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    matche.append(i.text)
matches = matche[0:18:2]
matches
# Out:
# ['31', '47', '36', '25', '31', '38', '36', '43', '20']

# %%
add = match + matches
add
# Out:
# ['35', '31', '47', '36', '25', '31', '38', '36', '43', '20']

# %%
point = []
for i in soup.find('td',class_="rankings-block__banner--points"):
    point.append(i.text)
point
# Out:
# ['3,965']

# %%
points = []
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    points.append(i.text)
pointss = points[1:19:2]
print(pointss)
# Out:
# ['3,504', '5,294', '3,988', '2,649', '3,141', '3,625', '3,099', '3,105', '1,419']

# %%
addd = point + pointss
addd
# Out:
# ['3,965',
#  '3,504',
#  '5,294',
#  '3,988',
#  '2,649',
#  '3,141',
#  '3,625',
#  '3,099',
#  '3,105',
#  '1,419']

# %%
rating = soup.find('td',class_="rankings-block__banner--rating u-text-right")
rating.text.split('\n                            ')[1]
# Out:
# '113'

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    ratings.append(i.text)
ratings
# Out:
# ['113',
#  '113',
#  '111',
#  '106',
#  '101',
#  '95',
#  '86',
#  '72',
#  '71',
#  '51',
#  '45',
#  '44',
#  '31',
#  '31',
#  '30',
#  '30',
#  '30',
#  '24',
#  '2']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Teams':team[0:10],'Matches':add[0:10],'Points':addd[0:10],'Rating':ratings[0:10]})
df
# Out:
#           Teams Matches Points Rating
# 0     Australia      35  3,965    113
# 1   New Zealand      31  3,504    113
# 2         India      47  5,294    111
# 3       England      36  3,988    106
# 4      Pakistan      25  2,649    101
# 5  South Africa      31  3,141     95
# 6    Bangladesh      38  3,625     86
# 7     Sri Lanka      36  3,099     72
# 8   West Indies      43  3,105     71
# 9   Afghanistan      20  1,419     51

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Batting | Player Rankings | ICC" property="og:title"/>
# ...

# %%
batsmen = []
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    batsmen.append(i.text)
batsmen
# Out:
# ['Babar Azam']

# %%
batsmens = []
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    batsmens.append(i.text.split('\n')[1])
batsmens
# Out:
# ['Rassie van der Dussen',
#  'Imam-ul-Haq',
#  'Shubman Gill',
#  'David Warner',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Steve Smith',
#  'Fakhar Zaman',
#  'Shai Hope',
#  'Kane Williamson',
#  'Jason Roy',
#  'Jonny Bairstow',
#  'Jos Buttler',
#  'Harry Tector',
#  'Mushfiqur Rahim',
#  'David Miller',
#  'Paul Stirling',
#  'Tamim Iqbal',
#  'Alex Carey',
#  'Joe Root',
#  'Rahmat Shah',
#  'Shreyas Iyer',
#  'Nicholas Pooran',
#  'Shakib Al Hasan',
#  'Travis Head',
#  'Gerhard Erasmus',
#  'Heinrich Klaasen',
#  'Glenn Maxwell',
#  'Temba Bavuma',
#  'Tom Latham',
#  'Sikandar Raza',
#  'Litton Das',
#  'Martin Guptill',
#  'Shikhar Dhawan',
#  'Dawid Malan',
#  'Lokesh Rahul',
#  'George Munsey',
#  'Mahmudullah',
#  'Aiden Markram',
#  'Najibullah Zadran',
#  'Devon Conway',
#  'Andrew Balbirnie',
#  'Kyle Coetzer',
#  'Ibrahim Zadran',
#  'Haris Sohail',
#  'Kariyawasa Asalanka',
#  'Assad Vala',
#  'Aaron Jones',
#  'Vriitya Aravind',
# ...

# %%
add = batsmen + batsmens
add
# Out:
# ['Babar Azam',
#  'Rassie van der Dussen',
#  'Imam-ul-Haq',
#  'Shubman Gill',
#  'David Warner',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Steve Smith',
#  'Fakhar Zaman',
#  'Shai Hope',
#  'Kane Williamson',
#  'Jason Roy',
#  'Jonny Bairstow',
#  'Jos Buttler',
#  'Harry Tector',
#  'Mushfiqur Rahim',
#  'David Miller',
#  'Paul Stirling',
#  'Tamim Iqbal',
#  'Alex Carey',
#  'Joe Root',
#  'Rahmat Shah',
#  'Shreyas Iyer',
#  'Nicholas Pooran',
#  'Shakib Al Hasan',
#  'Travis Head',
#  'Gerhard Erasmus',
#  'Heinrich Klaasen',
#  'Glenn Maxwell',
#  'Temba Bavuma',
#  'Tom Latham',
#  'Sikandar Raza',
#  'Litton Das',
#  'Martin Guptill',
#  'Shikhar Dhawan',
#  'Dawid Malan',
#  'Lokesh Rahul',
#  'George Munsey',
#  'Mahmudullah',
#  'Aiden Markram',
#  'Najibullah Zadran',
#  'Devon Conway',
#  'Andrew Balbirnie',
#  'Kyle Coetzer',
#  'Ibrahim Zadran',
#  'Haris Sohail',
#  'Kariyawasa Asalanka',
#  'Assad Vala',
#  'Aaron Jones',
# ...

# %%
team = []
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    team.append(i.text.split('\n')[2])
team
# Out:
# ['PAK']

# %%
teams = []
for i in soup.find_all('span',class_="table-body__logo-text"):
    teams.append(i.text)
teams
# Out:
# ['SA',
#  'PAK',
#  'IND',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'PAK',
#  'WI',
#  'NZ',
#  'ENG',
#  'ENG',
#  'ENG',
#  'IRE',
#  'BAN',
#  'SA',
#  'IRE',
#  'BAN',
#  'AUS',
#  'ENG',
#  'AFG',
#  'IND',
#  'WI',
#  'BAN',
#  'AUS',
#  'NAM',
#  'SA',
#  'AUS',
#  'SA',
#  'NZ',
#  'ZIM',
#  'BAN',
#  'NZ',
#  'IND',
#  'ENG',
#  'IND',
#  'SCO',
#  'BAN',
#  'SA',
#  'AFG',
#  'NZ',
#  'IRE',
#  'SCO',
#  'AFG',
#  'PAK',
#  'SL',
#  'PNG',
#  'USA',
#  'UAE',
#  'USA',
#  'AFG',
#  'AUS',
#  'SL',
#  'ZIM',
#  'IND',
#  'AFG',
#  'NEP',
#  'NED',
#  'USA',
#  'OMA',
#  'OMA',
#  'PAK',
#  'UAE',
#  'AFG',
#  'NEP',
#  'SA',
#  'SL',
#  'AUS',
#  'NZ',
#  'SL',
#  'SCO',
#  'IND',
#  'NZ',
#  'NED',
#  'SL',
#  'SL',
#  'SL',
#  'SCO',
#  'AUS',
#  'USA',
#  'NED',
#  'SL',
#  'NAM',
#  'NZ',
#  'ZIM',
#  'UAE',
#  'ENG',
#  'NZ',
#  'WI',
#  'ENG',
#  'PNG',
#  'SL',
#  'AFG',
#  'WI',
#  'SCO',
#  'NZ',
#  'NAM',
#  'BAN']

# %%
addd = team + teams
addd
# Out:
# ['PAK',
#  'SA',
#  'PAK',
#  'IND',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'PAK',
#  'WI',
#  'NZ',
#  'ENG',
#  'ENG',
#  'ENG',
#  'IRE',
#  'BAN',
#  'SA',
#  'IRE',
#  'BAN',
#  'AUS',
#  'ENG',
#  'AFG',
#  'IND',
#  'WI',
#  'BAN',
#  'AUS',
#  'NAM',
#  'SA',
#  'AUS',
#  'SA',
#  'NZ',
#  'ZIM',
#  'BAN',
#  'NZ',
#  'IND',
#  'ENG',
#  'IND',
#  'SCO',
#  'BAN',
#  'SA',
#  'AFG',
#  'NZ',
#  'IRE',
#  'SCO',
#  'AFG',
#  'PAK',
#  'SL',
#  'PNG',
#  'USA',
#  'UAE',
#  'USA',
#  'AFG',
#  'AUS',
#  'SL',
#  'ZIM',
#  'IND',
#  'AFG',
#  'NEP',
#  'NED',
#  'USA',
#  'OMA',
#  'OMA',
#  'PAK',
#  'UAE',
#  'AFG',
#  'NEP',
#  'SA',
#  'SL',
#  'AUS',
#  'NZ',
#  'SL',
#  'SCO',
#  'IND',
#  'NZ',
#  'NED',
#  'SL',
#  'SL',
#  'SL',
#  'SCO',
#  'AUS',
#  'USA',
#  'NED',
#  'SL',
#  'NAM',
#  'NZ',
#  'ZIM',
#  'UAE',
#  'ENG',
#  'NZ',
#  'WI',
#  'ENG',
#  'PNG',
#  'SL',
#  'AFG',
#  'WI',
#  'SCO',
#  'NZ',
#  'NAM',
#  'BAN']

# %%
rating = []
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    rating.append(i.text)
rating
# Out:
# ['887']

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell rating"):
    ratings.append(i.text)
ratings
# Out:
# ['777',
#  '740',
#  '738',
#  '726',
#  '719',
#  '718',
#  '707',
#  '702',
#  '699',
#  '698',
#  '686',
#  '682',
#  '669',
#  '658',
#  '650',
#  '646',
#  '643',
#  '640',
#  '633',
#  '631',
#  '631',
#  '628',
#  '624',
#  '620',
#  '617',
#  '616',
#  '614',
#  '612',
#  '612',
#  '609',
#  '598',
#  '595',
#  '586',
#  '585',
#  '580',
#  '572',
#  '571',
#  '569',
#  '568',
#  '557',
#  '555',
#  '555',
#  '543',
#  '543',
#  '543',
#  '542',
#  '536',
#  '536',
#  '534',
#  '525',
#  '523',
#  '523',
#  '523',
#  '518',
#  '514',
#  '511',
#  '511',
#  '507',
#  '506',
#  '501',
#  '499',
#  '496',
#  '495',
#  '492',
#  '492',
#  '490',
#  '490',
#  '490',
#  '490',
#  '489',
#  '485',
#  '482',
#  '479',
#  '478',
#  '475',
#  '474',
#  '471',
#  '471',
#  '469',
#  '461',
#  '459',
#  '459',
#  '458',
#  '457',
#  '456',
#  '453',
#  '447',
#  '447',
#  '446',
#  '438',
#  '433',
#  '431',
#  '429',
#  '426',
#  '425',
#  '422',
#  '422',
#  '421',
#  '417']

# %%
adddd = rating + ratings
adddd
# Out:
# ['887',
#  '777',
#  '740',
#  '738',
#  '726',
#  '719',
#  '718',
#  '707',
#  '702',
#  '699',
#  '698',
#  '686',
#  '682',
#  '669',
#  '658',
#  '650',
#  '646',
#  '643',
#  '640',
#  '633',
#  '631',
#  '631',
#  '628',
#  '624',
#  '620',
#  '617',
#  '616',
#  '614',
#  '612',
#  '612',
#  '609',
#  '598',
#  '595',
#  '586',
#  '585',
#  '580',
#  '572',
#  '571',
#  '569',
#  '568',
#  '557',
#  '555',
#  '555',
#  '543',
#  '543',
#  '543',
#  '542',
#  '536',
#  '536',
#  '534',
#  '525',
#  '523',
#  '523',
#  '523',
#  '518',
#  '514',
#  '511',
#  '511',
#  '507',
#  '506',
#  '501',
#  '499',
#  '496',
#  '495',
#  '492',
#  '492',
#  '490',
#  '490',
#  '490',
#  '490',
#  '489',
#  '485',
#  '482',
#  '479',
#  '478',
#  '475',
#  '474',
#  '471',
#  '471',
#  '469',
#  '461',
#  '459',
#  '459',
#  '458',
#  '457',
#  '456',
#  '453',
#  '447',
#  '447',
#  '446',
#  '438',
#  '433',
#  '431',
#  '429',
#  '426',
#  '425',
#  '422',
#  '422',
#  '421',
#  '417']

# %%
Top 10 ODI Batsmen along with the records of their team andrating

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Batsmen':add[0:10],'Team':addd[0:10],'Rating':adddd[0:10]})
df
# Out:
#                  Batsmen Team Rating
# 0             Babar Azam  PAK    887
# 1  Rassie van der Dussen   SA    777
# 2            Imam-ul-Haq  PAK    740
# 3           Shubman Gill  IND    738
# 4           David Warner  AUS    726
# 5            Virat Kohli  IND    719
# 6        Quinton de Kock   SA    718
# 7           Rohit Sharma  IND    707
# 8            Steve Smith  AUS    702
# 9           Fakhar Zaman  PAK    699

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Bowling | Player Rankings | ICC" property="og:title"/>
# ...

# %%
bowler = []
for i in soup.find_all('div',class_="rankings-block__banner--name-large"):
    bowler.append(i.text)
bowler
# Out:
# ['Josh Hazlewood']

# %%
bowlers = []
for i in soup.find_all('td',class_="table-body__cell rankings-table__name name"):
    bowlers.append(i.text.split('\n')[1])
bowlers
# Out:
# ['Trent Boult',
#  'Mohammed Siraj',
#  'Mitchell Starc',
#  'Matt Henry',
#  'Rashid Khan',
#  'Adam Zampa',
#  'Shaheen Afridi',
#  'Mujeeb Ur Rahman',
#  'Shakib Al Hasan',
#  'Mohammad Nabi',
#  'Alzarri Joseph',
#  'Chris Woakes',
#  'Mark Watt',
#  'Kagiso Rabada',
#  'Akeal Hosein',
#  'Pat Cummins',
#  'Mehedi Hasan',
#  'Jofra Archer',
#  'Mustafizur Rahman',
#  'Andy McBrine',
#  'Bernard Scholtz',
#  'Sandeep Lamichhane',
#  'Saurabh Netravalkar',
#  'Kuldeep Yadav',
#  'Lungi Ngidi',
#  'Jasprit Bumrah',
#  'Mohammad Nawaz',
#  'Adil Rashid',
#  'Mitchell Santner',
#  'Mohammad Shami',
#  'Wanindu Hasaranga',
#  'Bilal Khan',
#  'Mark Wood',
#  'Keshav Maharaj',
#  'Shadab Khan',
#  'Joshua Little',
#  'David Willey',
#  'Taskin Ahmed',
#  'Tim Southee',
#  'Ruben Trumpelmann',
#  'Fred Klaassen',
#  'Shardul Thakur',
#  'Yuzvendra Chahal',
#  'Lachlan Ferguson',
#  'Tabraiz Shamsi',
#  'Dushmantha Chameera',
#  'Rohan Mustafa',
#  'Taijul Islam',
#  'Safyaan Sharif',
# ...

# %%
add = bowler + bowlers
add
# Out:
# ['Josh Hazlewood',
#  'Trent Boult',
#  'Mohammed Siraj',
#  'Mitchell Starc',
#  'Matt Henry',
#  'Rashid Khan',
#  'Adam Zampa',
#  'Shaheen Afridi',
#  'Mujeeb Ur Rahman',
#  'Shakib Al Hasan',
#  'Mohammad Nabi',
#  'Alzarri Joseph',
#  'Chris Woakes',
#  'Mark Watt',
#  'Kagiso Rabada',
#  'Akeal Hosein',
#  'Pat Cummins',
#  'Mehedi Hasan',
#  'Jofra Archer',
#  'Mustafizur Rahman',
#  'Andy McBrine',
#  'Bernard Scholtz',
#  'Sandeep Lamichhane',
#  'Saurabh Netravalkar',
#  'Kuldeep Yadav',
#  'Lungi Ngidi',
#  'Jasprit Bumrah',
#  'Mohammad Nawaz',
#  'Adil Rashid',
#  'Mitchell Santner',
#  'Mohammad Shami',
#  'Wanindu Hasaranga',
#  'Bilal Khan',
#  'Mark Wood',
#  'Keshav Maharaj',
#  'Shadab Khan',
#  'Joshua Little',
#  'David Willey',
#  'Taskin Ahmed',
#  'Tim Southee',
#  'Ruben Trumpelmann',
#  'Fred Klaassen',
#  'Shardul Thakur',
#  'Yuzvendra Chahal',
#  'Lachlan Ferguson',
#  'Tabraiz Shamsi',
#  'Dushmantha Chameera',
#  'Rohan Mustafa',
#  'Taijul Islam',
# ...

# %%
team = []
for i in soup.find_all('div',class_="rankings-block__banner--nationality"):
    team.append(i.text.split('\n')[2])
team
# Out:
# ['AUS']

# %%
teams = []
for i in soup.find_all('span',class_="table-body__logo-text"):
    teams.append(i.text)
teams
# Out:
# ['NZ',
#  'IND',
#  'AUS',
#  'NZ',
#  'AFG',
#  'AUS',
#  'PAK',
#  'AFG',
#  'BAN',
#  'AFG',
#  'WI',
#  'ENG',
#  'SCO',
#  'SA',
#  'WI',
#  'AUS',
#  'BAN',
#  'ENG',
#  'BAN',
#  'IRE',
#  'NAM',
#  'NEP',
#  'USA',
#  'IND',
#  'SA',
#  'IND',
#  'PAK',
#  'ENG',
#  'NZ',
#  'IND',
#  'SL',
#  'OMA',
#  'ENG',
#  'SA',
#  'PAK',
#  'IRE',
#  'ENG',
#  'BAN',
#  'NZ',
#  'NAM',
#  'NED',
#  'IND',
#  'IND',
#  'NZ',
#  'SA',
#  'SL',
#  'UAE',
#  'BAN',
#  'SCO',
#  'OMA',
#  'SA',
#  'NEP',
#  'ZIM',
#  'IRE',
#  'PNG',
#  'OMA',
#  'PNG',
#  'UAE',
#  'IRE',
#  'SL',
#  'ENG',
#  'PAK',
#  'AUS',
#  'ZIM',
#  'IND',
#  'WI',
#  'NEP',
#  'ENG',
#  'AUS',
#  'USA',
#  'PAK',
#  'IRE',
#  'IND',
#  'UAE',
#  'IND',
#  'SL',
#  'SCO',
#  'ZIM',
#  'NAM',
#  'AUS',
#  'NZ',
#  'ENG',
#  'USA',
#  'SCO',
#  'SA',
#  'SA',
#  'UAE',
#  'SCO',
#  'ZIM',
#  'AFG',
#  'SL',
#  'OMA',
#  'IND',
#  'AFG',
#  'NEP',
#  'NED',
#  'AUS',
#  'SL',
#  'SL']

# %%
addd = team + teams
addd
# Out:
# ['AUS',
#  'NZ',
#  'IND',
#  'AUS',
#  'NZ',
#  'AFG',
#  'AUS',
#  'PAK',
#  'AFG',
#  'BAN',
#  'AFG',
#  'WI',
#  'ENG',
#  'SCO',
#  'SA',
#  'WI',
#  'AUS',
#  'BAN',
#  'ENG',
#  'BAN',
#  'IRE',
#  'NAM',
#  'NEP',
#  'USA',
#  'IND',
#  'SA',
#  'IND',
#  'PAK',
#  'ENG',
#  'NZ',
#  'IND',
#  'SL',
#  'OMA',
#  'ENG',
#  'SA',
#  'PAK',
#  'IRE',
#  'ENG',
#  'BAN',
#  'NZ',
#  'NAM',
#  'NED',
#  'IND',
#  'IND',
#  'NZ',
#  'SA',
#  'SL',
#  'UAE',
#  'BAN',
#  'SCO',
#  'OMA',
#  'SA',
#  'NEP',
#  'ZIM',
#  'IRE',
#  'PNG',
#  'OMA',
#  'PNG',
#  'UAE',
#  'IRE',
#  'SL',
#  'ENG',
#  'PAK',
#  'AUS',
#  'ZIM',
#  'IND',
#  'WI',
#  'NEP',
#  'ENG',
#  'AUS',
#  'USA',
#  'PAK',
#  'IRE',
#  'IND',
#  'UAE',
#  'IND',
#  'SL',
#  'SCO',
#  'ZIM',
#  'NAM',
#  'AUS',
#  'NZ',
#  'ENG',
#  'USA',
#  'SCO',
#  'SA',
#  'SA',
#  'UAE',
#  'SCO',
#  'ZIM',
#  'AFG',
#  'SL',
#  'OMA',
#  'IND',
#  'AFG',
#  'NEP',
#  'NED',
#  'AUS',
#  'SL',
#  'SL']

# %%
rating = []
for i in soup.find_all('div',class_="rankings-block__banner--rating"):
    rating.append(i.text)
rating
# Out:
# ['705']

# %%
ratings = []
for i in soup.find_all('td',class_="table-body__cell rating"):
    ratings.append(i.text)
ratings
# Out:
# ['694',
#  '691',
#  '686',
#  '676',
#  '659',
#  '652',
#  '641',
#  '637',
#  '636',
#  '631',
#  '625',
#  '612',
#  '611',
#  '600',
#  '597',
#  '597',
#  '597',
#  '596',
#  '594',
#  '593',
#  '589',
#  '588',
#  '578',
#  '576',
#  '562',
#  '552',
#  '549',
#  '547',
#  '541',
#  '540',
#  '536',
#  '532',
#  '523',
#  '521',
#  '520',
#  '516',
#  '514',
#  '514',
#  '512',
#  '508',
#  '507',
#  '505',
#  '503',
#  '500',
#  '500',
#  '496',
#  '492',
#  '487',
#  '479',
#  '478',
#  '475',
#  '468',
#  '467',
#  '464',
#  '464',
#  '462',
#  '462',
#  '461',
#  '458',
#  '456',
#  '454',
#  '449',
#  '448',
#  '447',
#  '446',
#  '446',
#  '445',
#  '441',
#  '438',
#  '436',
#  '436',
#  '435',
#  '428',
#  '427',
#  '427',
#  '426',
#  '426',
#  '426',
#  '421',
#  '421',
#  '420',
#  '418',
#  '414',
#  '413',
#  '410',
#  '408',
#  '407',
#  '402',
#  '401',
#  '400',
#  '399',
#  '398',
#  '395',
#  '391',
#  '390',
#  '384',
#  '382',
#  '382',
#  '382']

# %%
adddd = rating + ratings
adddd
# Out:
# ['705',
#  '694',
#  '691',
#  '686',
#  '676',
#  '659',
#  '652',
#  '641',
#  '637',
#  '636',
#  '631',
#  '625',
#  '612',
#  '611',
#  '600',
#  '597',
#  '597',
#  '597',
#  '596',
#  '594',
#  '593',
#  '589',
#  '588',
#  '578',
#  '576',
#  '562',
#  '552',
#  '549',
#  '547',
#  '541',
#  '540',
#  '536',
#  '532',
#  '523',
#  '521',
#  '520',
#  '516',
#  '514',
#  '514',
#  '512',
#  '508',
#  '507',
#  '505',
#  '503',
#  '500',
#  '500',
#  '496',
#  '492',
#  '487',
#  '479',
#  '478',
#  '475',
#  '468',
#  '467',
#  '464',
#  '464',
#  '462',
#  '462',
#  '461',
#  '458',
#  '456',
#  '454',
#  '449',
#  '448',
#  '447',
#  '446',
#  '446',
#  '445',
#  '441',
#  '438',
#  '436',
#  '436',
#  '435',
#  '428',
#  '427',
#  '427',
#  '426',
#  '426',
#  '426',
#  '421',
#  '421',
#  '420',
#  '418',
#  '414',
#  '413',
#  '410',
#  '408',
#  '407',
#  '402',
#  '401',
#  '400',
#  '399',
#  '398',
#  '395',
#  '391',
#  '390',
#  '384',
#  '382',
#  '382',
#  '382']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Bowlers':add[0:10],'Team':addd[0:10],'Rating':adddd[0:10]})
df
# Out:
#             Bowlers Team Rating
# 0    Josh Hazlewood  AUS    705
# 1       Trent Boult   NZ    694
# 2    Mohammed Siraj  IND    691
# 3    Mitchell Starc  AUS    686
# 4        Matt Henry   NZ    676
# 5       Rashid Khan  AFG    659
# 6        Adam Zampa  AUS    652
# 7    Shaheen Afridi  PAK    641
# 8  Mujeeb Ur Rahman  AFG    637
# 9   Shakib Al Hasan  BAN    636
